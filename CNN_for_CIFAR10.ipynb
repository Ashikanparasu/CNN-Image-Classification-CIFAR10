# %%
import torch 
import torch.nn as nn 
import torch.optim as optim

import torchvision
from torchvision.datasets import CIFAR10

# %%
# Out:
# Requirement already satisfied: torch in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (2.12.1)
# Collecting torchvision
#   Downloading torchvision-0.27.1-cp310-cp310-win_amd64.whl (3.5 MB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl (328 kB)
# Requirement already satisfied: jinja2 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: filelock in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.29.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: setuptools<82 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torch) (57.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: numpy in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tansam-3\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch) (3.0.3)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.11.0 torchvision-0.27.1
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'C:\Users\TANSAM-3\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#datasets & Dataloaders

from torch.utils.data import DataLoader
import torchvision.transforms as transforms

transform = transforms.Compose([

    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    
]) 

trainset = CIFAR10(root = "./data",train=True , download = True,transform = transform)
testset = CIFAR10(root = "./data",train=False , download = True,transform = transform)
# Out:
# 0.6%

# %%
trainloader = DataLoader(trainset , batch_size = 64 , shuffle =True)
testloader =  DataLoader(testset , batch_size = 64)

# %% [markdown]
# ### Build the CNN
